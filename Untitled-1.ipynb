# %%
from common import *
scene3_point = load_json('resources_stable/BinOutput/Scene/Point/scene3_point.json')

print(encode_json(semi_flatten(scene3_point, 1), sort_ints=True))
# Out:
# {
# 	"points":{
# 		"1":{
# 			"$type":"DungeonEntry",
# 			"heightSpeed":70120001,
# 			"height":1,
# 			"pos":[2163.6640625,235.37120056152344,-1642.4210205078125],
# 			"rot":[0,275.8915100097656,0],
# 			"tranPos":[2154.554931640625,234.81402587890625,-1638.244140625],
# 			"tranRot":[0,114.20144653320312,0],
# 			"alias":"",
# 			"cutsceneList":[4],
# 			"dungeonIds":[4007],
# 			"size":[10,10,10],
# 			"titleTextID":"UI_DUNGEON_ENTRY_1",
# 			"NIPKCKIFCGK":0
# 		},
# 		"2":{
# 			"$type":"DungeonExit",
# 			"heightSpeed":70010002,
# 			"height":1,
# 			"pos":[2155.053955078125,234.59710693359375,-1638.530029296875],
# 			"rot":[3.954699993133545,321.1448974609375,359.92059326171875],
# 			"unlocked":true,
# 			"alias":"",
# 			"JAGOPOODDAJ":1
# 		},
# 		"3":{
# 			"$type":"SceneTransPoint",
# 			"type":"TOWER",
# 			"heightSpeed":70110001,
# 			"height":3,
# 			"pos":[1859.3399658203125,258.0365905761719,-575.5999755859375],
# 			"rot":[0,241.79296875,0],
# ...
